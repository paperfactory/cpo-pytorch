# %%
import itertools
import pandas as pd
import numpy as np
import random
import csv
import time

import matplotlib.pyplot as plt

# %%
class DataGenerator():
    def __init__(self, datapath, itempath):
        '''
        Load data from the DB MovieLens
        List the users and the items
        List all the users historic
        '''
        self.data  = self.load_datas(datapath, itempath)
        self.users = self.data['userId'].unique()   #list of all users
        self.items = self.data['itemId'].unique()   #list of all items
        self.histo = self.gen_histo()
        self.train = []
        self.test  = []

    def load_datas(self, datapath, itempath):
        '''
        Load the data and merge the name of each movie. 
        A row corresponds to a rate given by a user to a movie.

         Parameters
        ----------
        datapath :  string
                    path to the data 100k MovieLens
                    contains usersId;itemId;rating 
        itempath :  string
                    path to the data 100k MovieLens
                    contains itemId;itemName
         Returns
        -------
        result :    DataFrame
                    Contains all the ratings 
        '''
        data = pd.read_csv(datapath, sep='\t', 
                           names=['userId', 'itemId', 'rating', 'timestamp'])
        movie_titles = pd.read_csv(itempath, sep='|', names=['itemId', 'itemName'],
                               usecols=range(2), encoding='latin-1')
        return data.merge(movie_titles,on='itemId', how='left')


    def gen_histo(self):
        '''
        Group all rates given by users and store them from older to most recent.

        Returns
        -------
        result :    List(DataFrame)
                    List of the historic for each user
                    [userId  itemId  rating  timestamp itemName] for each userId 
        '''
        historic_users = []
        for i, u in enumerate(self.users):
          temp = self.data[self.data['userId'] == u]
          temp = temp.sort_values('timestamp').reset_index()
          temp.drop('index', axis=1, inplace=True)
          historic_users.append(temp)
        return historic_users

    def sample_histo(self, user_histo, action_ratio=0.8, max_samp_by_user=5,  max_state=100, max_action=50, nb_states=[], nb_actions=[]):
        '''
        For a given historic, make one or multiple sampling.
        If no optional argument given for nb_states and nb_actions, then the sampling
        is random and each sample can have differents size for action and state.
        To normalize sampling we need to give list of the numbers of states and actions
        to be sampled.

        Parameters
        ----------
        user_histo :  DataFrame
                          historic of user
        delimiter :       string, optional
                          delimiter for the csv
        action_ratio :    float, optional
                          ratio form which movies in history will be selected
        max_samp_by_user: int, optional
                          Nulber max of sample to make by user
        max_state :       int, optional
                          Number max of movies to take for the 'state' column
        max_action :      int, optional
                          Number max of movies to take for the 'action' action
        nb_states :       array(int), optional
                          Numbers of movies to be taken for each sample made on user's historic
        nb_actions :      array(int), optional
                          Numbers of rating to be taken for each sample made on user's historic

        Returns
        -------
        states :         List(String)
                         All the states sampled, format of a sample: itemId&rating
        actions :        List(String)
                         All the actions sampled, format of a sample: itemId&rating


        Notes
        -----
        States must be before(timestamp<) the actions.
        If given, size of nb_states is the numbller of sample by user
        sizes of nb_states and nb_actions must be equals
        '''

        n = len(user_histo)
        sep = int(action_ratio * n)
        nb_sample = random.randint(1, max_samp_by_user)
        if not nb_states:
          nb_states = [min(random.randint(1, sep), max_state) for i in range(nb_sample)]
        if not nb_actions:
          nb_actions = [min(random.randint(1, n - sep), max_action) for i in range(nb_sample)]
        assert len(nb_states) == len(nb_actions), 'Given array must have the same size'

        states  = []
        actions = []
        # SELECT SAMPLES IN HISTO
        for i in range(len(nb_states)):
          sample_states = user_histo.iloc[0:sep].sample(nb_states[i])
          sample_actions = user_histo.iloc[-(n - sep):].sample(nb_actions[i])

          sample_state =  []
          sample_action = []
          for j in range(nb_states[i]):
            row   = sample_states.iloc[j]
            # FORMAT STATE
            state = str(row.loc['itemId']) + '&' + str(row.loc['rating'])
            sample_state.append(state)

          for j in range(nb_actions[i]):
            row    = sample_actions.iloc[j]
            # FORMAT ACTION
            action = str(row.loc['itemId']) + '&' + str(row.loc['rating'])
            sample_action.append(action)

          states.append(sample_state)
          actions.append(sample_action)
        return states, actions

    def gen_train_test(self, test_ratio, seed=None):
        '''
        Shuffle the historic of users and separate it in a train and a test set.
        Store the ids for each set.
        An user can't be in both set.

         Parameters
        ----------
        test_ratio :  float
                      Ratio to control the sizes of the sets
        seed       :  float
                      Seed on the shuffle
        '''
        n = len(self.histo)

        if seed is not None:
          random.Random(seed).shuffle(self.histo)
        else:
          random.shuffle(self.histo)

        self.train = self.histo[:int((test_ratio * n))]
        self.test  = self.histo[int((test_ratio * n)):]
        self.user_train = [h.iloc[0,0] for h in self.train]
        self.user_test  = [h.iloc[0,0] for h in self.test]


    def write_csv(self, filename, histo_to_write, delimiter=';', action_ratio=0.8, max_samp_by_user=5, max_state=100, max_action=50, nb_states=[], nb_actions=[]):
        '''
        From  a given historic, create a csv file with the format:
        columns : state;action_reward;n_state
        rows    : itemid&rating1 | itemid&rating2 | ... ; itemid&rating3 | ... | itemid&rating4; itemid&rating1 | itemid&rating2 | itemid&rating3 | ... | item&rating4
        at filename location.

        Parameters
        ----------
        filename :        string
                          path to the file to be produced
        histo_to_write :  List(DataFrame)
                          List of the historic for each user
        delimiter :       string, optional
                          delimiter for the csv
        action_ratio :    float, optional
                          ratio form which movies in history will be selected
        max_samp_by_user: int, optional
                          Nulber max of sample to make by user
        max_state :       int, optional
                          Number max of movies to take for the 'state' column
        max_action :      int, optional
                          Number max of movies to take for the 'action' action
        nb_states :       array(int), optional
                          Numbers of movies to be taken for each sample made on user's historic
        nb_actions :      array(int), optional
                          Numbers of rating to be taken for each sample made on user's historic

        Notes
        -----
        if given, size of nb_states is the numbller of sample by user
        sizes of nb_states and nb_actions must be equals

        '''
        with open(filename, mode='w') as file:
          f_writer = csv.writer(file, delimiter=delimiter)
          f_writer.writerow(['state', 'action_reward', 'n_state'])
          for user_histo in histo_to_write:
            states, actions = self.sample_histo(user_histo, action_ratio, max_samp_by_user, max_state, max_action, nb_states, nb_actions)
            for i in range(len(states)):
              # FORMAT STATE
              state_str   = '|'.join(states[i])
              # FORMAT ACTION
              action_str  = '|'.join(actions[i])
              # FORMAT N_STATE
              n_state_str = state_str + '|' + action_str
              f_writer.writerow([state_str, action_str, n_state_str])

# %%
dg = DataGenerator('ml-100k/u.data', 'ml-100k/u.item')
# dg.gen_train_test(0.8, seed=42)

# %%
dg.histo
# Out:
# [    userId  itemId  rating  timestamp  \
#  0      196     242       3  881250949
#  1      196     269       3  881250949
#  2      196     286       5  881250949
#  3      196     306       4  881251021
#  4      196     340       3  881251045
#  5      196    1022       4  881251143
#  6      196     251       3  881251274
#  7      196     257       2  881251577
#  8      196    1007       4  881251601
#  9      196    1241       3  881251642
#  10     196     428       4  881251702
#  ..     ...     ...     ...        ...
#  87     115     969       1  881172183
#  88     115     644       3  881172183
#  89     115      83       3  881172183
#  90     115     178       5  881172246
#  91     115     543       2  881172303
#
#                                         itemName
#  0                         Rainmaker, The (1997)
#  1                        Full Monty, The (1997)
#  2                      L.A. Confidential (1997)
#  3                              Big Night (1996)
#  4                               Sleepers (1996)
#  ..                                          ...
#  87  Winnie the Pooh and the Blustery Day (1968)
#  88                   Thin Blue Line, The (1988)
#  89                Much Ado About Nothing (1993)
#  90                          12 Angry Men (1957)
#  91                       Misérables, Les (1995)
#
#  [92 rows x 5 columns],
#      userId  itemId  rating  timestamp                    itemName
#  0      253     331       3  891627664            Edge, The (1997)
#  1      253     300       4  891627724        Air Force One (1997)
#  2      253     689       5  891627775          Jackal, The (1997)
#  3      253     328       4  891627790    Conspiracy Theory (1997)
#  4      253     751       3  891627815  Tomorrow Never Dies (1997)
#  ..     ...     ...     ...        ...                         ...
#  92     253     448       2  891628883            Omen, The (1976)
#  93     253     333       2  891628883            Game, The (1997)
#  94     253     175       2  891628884               Brazil (1985)
#  95     253     192       1  891628884          Raging Bull (1980)
#  96     253     685       2  891628884   Executive Decision (1996)
#
#  [97 rows x 5 columns],
#       userId  itemId  rating  timestamp                                itemName
#  0       305     300       3  886307828                    Air Force One (1997)
#  1       305     286       4  886307828             English Patient, The (1996)
#  2       305     242       5  886307828                            Kolya (1996)
#  3       305     690       4  886307828             Seven Years in Tibet (1997)
#  4       305     302       4  886307860                L.A. Confidential (1997)
#  ..      ...     ...     ...        ...                                     ...
#  217     305     550       3  886325023       Die Hard: With a Vengeance (1995)
#  218     305      66       3  886325023          While You Were Sleeping (1995)
#  219     305     778       4  886325023                 Don Juan DeMarco (1995)
#  220     305     163       3  886325627  Return of the Pink Panther, The (1974)
#  221     305      33       3  886325627                        Desperado (1995)
#
#  [222 rows x 5 columns],
#       userId  itemId  rating  timestamp  \
#  0         6     242       4  883268170
#  1         6     286       2  883268170
#  2         6     269       4  883268222
#  3         6     302       4  883268222
#  4         6     306       4  883268246
#  ..      ...     ...     ...        ...
#  206       6      28       2  883603013
#  207       6     518       3  883603042
#  208       6     539       2  883681433
#  209       6     465       1  883683508
#  210       6     272       4  883717304
#
#                                          itemName
#  0                                   Kolya (1996)
#  1                    English Patient, The (1996)
#  2                         Full Monty, The (1997)
#  3                       L.A. Confidential (1997)
#  4    Mrs. Brown (Her Majesty, Mrs. Brown) (1997)
#  ..                                           ...
#  206                             Apollo 13 (1995)
#  207                     Miller's Crossing (1990)
#  208                            Mouse Hunt (1997)
#  209                      Jungle Book, The (1994)
#  210                     Good Will Hunting (1997)
#
#  [211 rows x 5 columns],
#       userId  itemId  rating  timestamp                       itemName
#  0        62     302       3  879371909       L.A. Confidential (1997)
#  1        62     258       5  879371909                 Contact (1997)
#  2        62     328       3  879371909       Conspiracy Theory (1997)
#  3        62     271       1  879371909       Starship Troopers (1997)
#  4        62     288       2  879371909                  Scream (1996)
#  ..      ...     ...     ...        ...                            ...
#  227      62    1130       4  879376686          Jupiter's Wife (1994)
#  228      62     138       1  879376709    D3: The Mighty Ducks (1996)
#  229      62    1091       3  879376709           Pete's Dragon (1977)
#  230      62     167       2  879376727        Private Benjamin (1980)
#  231      62     401       3  879376727  Brady Bunch Movie, The (1995)
#
#  [232 rows x 5 columns],
#       userId  itemId  rating  timestamp                              itemName
#  0       286     289       5  875806672                          Evita (1996)
#  1       286     288       5  875806672                         Scream (1996)
#  2       286     988       3  875806722  Beautician and the Beast, The (1997)
#  3       286     237       2  875806800                  Jerry Maguire (1996)
#  4       286     408       4  875806800                 Close Shave, A (1995)
#  ..      ...     ...     ...        ...                                   ...
#  283     286     768       3  889652968                         Casper (1995)
#  284     286    1060       5  889652989   Adventures of Pinocchio, The (1996)
#  285     286    1118       1  889652989                    Up in Smoke (1978)
#  286     286     139       3  889653012                  Love Bug, The (1969)
#  287     286     934       3  889653107           Preacher's Wife, The (1996)
#
#  [288 rows x 5 columns],
#       userId  itemId  rating  timestamp                          itemName
#  0       200     304       5  876041644              Fly Away Home (1996)
#  1       200     258       4  876041644                    Contact (1997)
#  2       200     325       5  876041719                      Crash (1996)
#  3       200     243       3  876041719              Jungle2Jungle (1997)
#  4       200     125       5  876041895                 Phenomenon (1996)
#  ..      ...     ...     ...        ...                               ...
#  211     200    1034       3  891825521                 Quest, The (1996)
#  212     200     831       4  891825565           Escape from L.A. (1996)
#  213     200     982       2  891825589               Maximum Risk (1996)
#  214     200     743       3  891825607  Crow: City of Angels, The (1996)
#  215     200     931       3  891825627  Island of Dr. Moreau, The (1996)
#
#  [216 rows x 5 columns],
#       userId  itemId  rating  timestamp  \
#  0       210     300       4  887730066
#  1       210      23       5  887730102
#  2       210      58       4  887730177
#  3       210     662       2  887730221
#  4       210     969       4  887730221
#  ..      ...     ...     ...        ...
#  127     210     167       4  891036054
#  128     210      49       3  891036116
#  129     210      94       4  891036181
#  130     210      72       3  891036310
#  131     210     105       3  891036331
#
#                                          itemName
#  0                           Air Force One (1997)
#  1                             Taxi Driver (1976)
#  2                               Quiz Show (1994)
#  3                       Somewhere in Time (1980)
#  4    Winnie the Pooh and the Blustery Day (1968)
#  ..                                           ...
#  127                      Private Benjamin (1980)
#  128                                  I.Q. (1994)
#  129                            Home Alone (1990)
#  130                             Mask, The (1994)
#  131                            Sgt. Bilko (1996)
#
#  [132 rows x 5 columns],
#       userId  itemId  rating  timestamp                     itemName
#  0       224     286       3  888081843  English Patient, The (1996)
#  1       224     313       5  888081843               Titanic (1997)
#  2       224     300       4  888081843         Air Force One (1997)
#  3       224     751       3  888081913   Tomorrow Never Dies (1997)
#  4       224     328       4  888081947     Conspiracy Theory (1997)
#  ..      ...     ...     ...        ...                          ...
#  136     224     403       4  888104522                Batman (1989)
#  137     224     239       4  888104554              Sneakers (1992)
#  138     224    1401       1  888104554          M. Butterfly (1993)
#  139     224    1208       1  888104554         Kiss of Death (1995)
#  140     224    1381       3  888104589          Losing Chase (1996)
#
#  [141 rows x 5 columns],
#       userId  itemId  rating  timestamp                        itemName
#  0       303     258       4  879465986                  Contact (1997)
#  1       303     286       5  879465986     English Patient, The (1996)
#  2       303     302       4  879465986        L.A. Confidential (1997)
#  3       303     269       5  879466018          Full Monty, The (1997)
#  4       303     872       3  879466018               Love Jones (1997)
#  ..      ...     ...     ...        ...                             ...
#  479     303     687       1  879544923            McHale's Navy (1997)
#  480     303     678       1  879544946                  Volcano (1997)
#  481     303    1088       2  879544946              Double Team (1997)
#  482     303    1089       1  879544978  Speed 2: Cruise Control (1997)
#  483     303     330       3  879552065                      187 (1997)
#
#  [484 rows x 5 columns],
#      userId  itemId  rating  timestamp                                itemName
#  0      122     269       5  879269963                  Full Monty, The (1997)
#  1      122      28       4  879270084                        Apollo 13 (1995)
#  2      122     513       4  879270084                   Third Man, The (1949)
#  3      122     357       3  879270084  One Flew Over the Cuckoo's Nest (1975)
#  4      122     175       5  879270084                           Brazil (1985)
#  ..     ...     ...     ...        ...                                     ...
#  56     122     737       4  879270874                           Sirens (1994)
#  57     122     470       3  879270901                        Tombstone (1993)
#  58     122    1074       4  879270901                    Reality Bites (1994)
#  59     122    1168       4  879270902                    Little Buddha (1993)
#  60     122    1044       5  879270923                       Paper, The (1994)
#
#  [61 rows x 5 columns],
#       userId  itemId  rating  timestamp                                itemName
#  0       194     294       4  879520305                        Liar Liar (1997)
#  1       194     286       1  879520306             English Patient, The (1996)
#  2       194     991       2  879520306                    Keys to Tulsa (1997)
#  3       194     259       2  879520306             George of the Jungle (1997)
#  4       194     321       3  879520306                           Mother (1996)
#  ..      ...     ...     ...        ...                                     ...
#  300     194     540       1  879554950                      Money Train (1995)
#  301     194     450       1  879555001  Star Trek V: The Final Frontier (1989)
#  302     194     712       3  879555147                          Tin Men (1987)
#  303     194    1408       1  879555267                            Gordy (1995)
#  304     194    1207       1  879555410                             Jade (1995)
#
#  [305 rows x 5 columns],
#       userId  itemId  rating  timestamp                      itemName
#  0       291     324       1  874805453           Lost Highway (1997)
#  1       291     288       5  874805453                 Scream (1996)
#  2       291     245       2  874805577       Devil's Own, The (1997)
#  3       291     325       4  874805610                  Crash (1996)
#  4       291     237       4  874805668          Jerry Maguire (1996)
#  ..      ...     ...     ...        ...                           ...
#  291     291     574       1  875087656          Boxing Helena (1993)
#  292     291    1210       4  875087656             Virtuosity (1995)
#  293     291     769       1  875087673                  Congo (1995)
#  294     291     582       4  875087720             Piano, The (1993)
#  295     291     496       5  875088191  It's a Wonderful Life (1946)
#
#  [296 rows x 5 columns],
#       userId  itemId  rating  timestamp                     itemName
#  0       234     313       4  891033261               Titanic (1997)
#  1       234     268       2  891033261           Chasing Amy (1997)
#  2       234     242       4  891033261                 Kolya (1996)
#  3       234     286       3  891033314  English Patient, The (1996)
#  4       234     321       2  891033393                Mother (1996)
#  ..      ...     ...     ...        ...                          ...
#  475     234     628       2  892826612              Sleepers (1996)
#  476     234     956       3  892826643         Nobody's Fool (1994)
#  477     234     152       4  892826701               Sleeper (1973)
#  478     234     648       3  892826760        Quiet Man, The (1952)
#  479     234     301       3  892826947              In & Out (1997)
#
#  [480 rows x 5 columns],
#       userId  itemId  rating  timestamp                     itemName
#  0       119     300       5  874774286         Air Force One (1997)
#  1       119     286       5  874774286  English Patient, The (1996)
#  2       119     322       4  874774449        Murder at 1600 (1997)
#  3       119     323       4  874774449          Dante's Peak (1997)
#  4       119     866       3  874774575               Michael (1996)
#  ..      ...     ...     ...        ...                          ...
#  176     119     269       3  892564213       Full Monty, The (1997)
#  177     119     294       1  892564313             Liar Liar (1997)
#  178     119     917       4  892564349        Mercury Rising (1998)
#  179     119     916       1  892564442         Lost in Space (1998)
#  180     119     338       1  892565167                  Bean (1997)
#
#  [181 rows x 5 columns],
#      userId  itemId  rating  timestamp  \
#  0      167     290       3  892737936
#  1      167     235       3  892737972
#  2      167     240       1  892737972
#  3      167     237       4  892737972
#  4      167     288       3  892737972
#  ..     ...     ...     ...        ...
#  64     167     486       4  892738452
#  65     167     530       5  892738453
#  66     167     435       5  892738453
#  67     167     733       2  892738453
#  68     167     133       5  892738453
#
#                                       itemName
#  0                     Fierce Creatures (1997)
#  1                        Mars Attacks! (1996)
#  2      Beavis and Butt-head Do America (1996)
#  3                        Jerry Maguire (1996)
#  4                               Scream (1996)
#  ..                                        ...
#  64                             Sabrina (1954)
#  65          Man Who Would Be King, The (1975)
#  66  Butch Cassidy and the Sundance Kid (1969)
#  67                             Go Fish (1994)
#  68                  Gone with the Wind (1939)
#
#  [69 rows x 5 columns],
#       userId  itemId  rating  timestamp                     itemName
#  0       299     286       4  877618524  English Patient, The (1996)
#  1       299     294       2  877618584             Liar Liar (1997)
#  2       299     303       3  877618584           Ulee's Gold (1997)
#  3       299     288       3  877618584                Scream (1996)
#  4       299     300       4  877618619         Air Force One (1997)
#  ..      ...     ...     ...        ...                          ...
#  275     299    1036       2  889503856        Drop Dead Fred (1991)
#  276     299      81       4  889504036  Hudsucker Proxy, The (1994)
#  277     299     333       4  892249868             Game, The (1997)
#  278     299     916       3  892249868         Lost in Space (1998)
#  279     299     915       4  892250102        Primary Colors (1998)
#
#  [280 rows x 5 columns],
#       userId  itemId  rating  timestamp                         itemName
#  0       308     288       4  887736408                    Scream (1996)
#  1       308     319       4  887736408  Everyone Says I Love You (1996)
#  2       308     313       3  887736408                   Titanic (1997)
#  3       308     309       1  887736408                  Deceiver (1997)
#  4       308     264       2  887736408                     Mimic (1997)
#  ..      ...     ...     ...        ...                              ...
#  392     308     824       3  887742013     Great White Hype, The (1996)
#  393     308     928       4  887742103                Craft, The (1996)
#  394     308    1047       3  887742130              Multiplicity (1996)
#  395     308     122       4  887742165            Cable Guy, The (1996)
#  396     308     254       2  887742454            Batman & Robin (1997)
#
#  [397 rows x 5 columns],
#       userId  itemId  rating  timestamp                              itemName
#  0        95     289       2  879191590                          Evita (1996)
#  1        95     137       3  879192404                      Big Night (1996)
#  2        95      24       3  879192542            Rumble in the Bronx (1995)
#  3        95      25       3  879192597                  Birdcage, The (1996)
#  4        95     237       2  879192708                  Jerry Maguire (1996)
#  ..      ...     ...     ...        ...                                   ...
#  273      95     398       1  888956804              Super Mario Bros. (1993)
#  274      95    1090       1  888956869                         Sliver (1993)
#  275      95    1230       1  888956901  Ready to Wear (Pret-A-Porter) (1994)
#  276      95      78       3  888956901                     Free Willy (1993)
#  277      95     395       3  888956928      Robin Hood: Men in Tights (1993)
#
#  [278 rows x 5 columns],
#       userId  itemId  rating  timestamp  \
#  0        38     916       5  892428188
#  1        38     288       5  892428188
#  2        38     313       5  892428216
#  3        38     294       5  892428584
#  4        38     678       5  892428658
#  ..      ...     ...     ...        ...
#  116      38     758       1  892434626
#  117      38    1029       1  892434626
#  118      38     940       1  892434742
#  119      38     672       3  892434800
#  120      38     122       1  892434801
#
#                                        itemName
#  0                         Lost in Space (1998)
#  1                                Scream (1996)
#  2                               Titanic (1997)
#  3                             Liar Liar (1997)
#  4                               Volcano (1997)
#  ..                                         ...
#  116  Lawnmower Man 2: Beyond Cyberspace (1996)
#  117                           Jury Duty (1995)
#  118                            Airheads (1994)
#  119                            Candyman (1992)
#  120                      Cable Guy, The (1996)
#
#  [121 rows x 5 columns],
#       userId  itemId  rating  timestamp                            itemName
#  0       102     258       4  875886337                      Contact (1997)
#  1       102     300       3  875886434                Air Force One (1997)
#  2       102     319       4  875886434     Everyone Says I Love You (1996)
#  3       102     298       3  875886827                     Face/Off (1997)
#  4       102     248       3  877915935          Grosse Pointe Blank (1997)
#  ..      ...     ...     ...        ...                                 ...
#  211     102     577       3  892993895                    Coneheads (1993)
#  212     102     167       2  892993927             Private Benjamin (1980)
#  213     102     856       2  892993927               Night on Earth (1991)
#  214     102    1052       2  892993983  Dracula: Dead and Loving It (1995)
#  215     102    1030       1  892994075     Beverly Hillbillies, The (1993)
#
#  [216 rows x 5 columns],
#      userId  itemId  rating  timestamp                              itemName
#  0       63     258       3  875746809                        Contact (1997)
#  1       63     268       3  875746809                    Chasing Amy (1997)
#  2       63     302       3  875746809              L.A. Confidential (1997)
#  3       63     286       4  875746809           English Patient, The (1996)
#  4       63     321       3  875746917                         Mother (1996)
#  ..     ...     ...     ...        ...                                   ...
#  88      63     108       2  875748164  Kids in the Hall: Brain Candy (1996)
#  89      63    1028       3  875748198               Grumpier Old Men (1995)
#  90      63      79       3  875748245                  Fugitive, The (1993)
#  91      63     480       3  875748245             North by Northwest (1959)
#  92      63     300       4  875748326                  Air Force One (1997)
#
#  [93 rows x 5 columns],
#       userId  itemId  rating  timestamp                  itemName
#  0       160       9       3  876767023   Dead Man Walking (1995)
#  1       160     408       4  876767023     Close Shave, A (1995)
#  2       160     100       5  876767023              Fargo (1996)
#  3       160     137       4  876767299          Big Night (1996)
#  4       160     825       2  876767299       Arrival, The (1996)
#  ..      ...     ...     ...        ...                       ...
#  115     160     955       4  876862243     Before Sunrise (1995)
#  116     160     531       5  876942699              Shine (1996)
#  117     160     302       5  878078074  L.A. Confidential (1997)
#  118     160     328       3  878078096  Conspiracy Theory (1997)
#  119     160     325       3  878078115              Crash (1996)
#
#  [120 rows x 5 columns],
#      userId  itemId  rating  timestamp  \
#  0       50     268       4  877051656
#  1       50     319       5  877051687
#  2       50     288       4  877052008
#  3       50     324       5  877052008
#  4       50     327       3  877052093
#  5       50     475       5  877052167
#  6       50       9       4  877052297
#  7       50     547       4  877052297
#  8       50    1010       5  877052329
#  9       50     246       3  877052329
#  10      50     286       2  877052400
#  11      50     276       2  877052400
#  12      50     124       1  877052400
#  13      50     325       1  877052400
#  14      50     100       2  877052400
#  15      50     508       5  877052438
#  16      50      15       2  877052438
#  17      50    1084       5  877052501
#  18      50     125       2  877052502
#  19      50     253       5  877052550
#  20      50     823       3  877052784
#  21      50    1008       5  877052805
#  22      50     544       4  877052937
#  23      50     123       4  877052958
#
#                                            itemName
#  0                               Chasing Amy (1997)
#  1                  Everyone Says I Love You (1996)
#  2                                    Scream (1996)
#  3                              Lost Highway (1997)
#  4                                  Cop Land (1997)
#  5                             Trainspotting (1996)
#  6                          Dead Man Walking (1995)
#  7            Young Poisoner's Handbook, The (1995)
#  8                                  Basquiat (1996)
#  9                               Chasing Amy (1997)
#  10                     English Patient, The (1996)
#  11                        Leaving Las Vegas (1995)
#  12                                Lone Star (1996)
#  13                                    Crash (1996)
#  14                                    Fargo (1996)
#  15              People vs. Larry Flynt, The (1996)
#  16                       Mr. Holland's Opus (1995)
#  17                    Anne Frank Remembered (1995)
#  18                               Phenomenon (1996)
#  19                         Pillow Book, The (1995)
#  20                         Mulholland Falls (1996)
#  21                       I Shot Andy Warhol (1996)
#  22  Things to Do in Denver when You're Dead (1995)
#  23                         Frighteners, The (1996)  ,
#       userId  itemId  rating  timestamp  \
#  0       301       7       4  882074236
#  1       301     250       4  882074236
#  2       301     109       5  882074236
#  3       301     127       4  882074262
#  4       301       9       3  882074291
#  ..      ...     ...     ...        ...
#  270     301    1228       4  882079423
#  271     301      41       3  882079446
#  272     301     138       2  882079446
#  273     301     217       3  882079503
#  274     301     719       4  882079542
#
#                                             itemName
#  0                             Twelve Monkeys (1995)
#  1                         Fifth Element, The (1997)
#  2    Mystery Science Theater 3000: The Movie (1996)
#  3                             Godfather, The (1972)
#  4                           Dead Man Walking (1995)
#  ..                                              ...
#  270            Under Siege 2: Dark Territory (1995)
#  271                            Billy Madison (1995)
#  272                     D3: The Mighty Ducks (1996)
#  273                    Bram Stoker's Dracula (1992)
#  274                           Canadian Bacon (1994)
#
#  [275 rows x 5 columns],
#      userId  itemId  rating  timestamp                             itemName
#  0      225     286       4  879539027          English Patient, The (1996)
#  1      225     245       2  879539315              Devil's Own, The (1997)
#  2      225     479       4  879539614                       Vertigo (1958)
#  3      225     427       5  879539615         To Kill a Mockingbird (1962)
#  4      225     237       5  879539643                 Jerry Maguire (1996)
#  5      225      98       5  879539672     Silence of the Lambs, The (1991)
#  6      225     510       5  879539672        Magnificent Seven, The (1954)
#  7      225     193       4  879539727              Right Stuff, The (1983)
#  8      225      64       4  879539727     Shawshank Redemption, The (1994)
#  9      225     492       4  879539767                  East of Eden (1955)
#  10     225     478       5  879539767       Philadelphia Story, The (1940)
#  11     225     215       5  879539789               Field of Dreams (1989)
#  12     225     603       5  879540649                   Rear Window (1954)
#  13     225     606       5  879540649                 All About Eve (1950)
#  14     225     418       5  879540650                    Cinderella (1950)
#  15     225      22       5  879540678                    Braveheart (1995)
#  16     225     194       5  879540678                    Sting, The (1973)
#  17     225     566       4  879540678      Clear and Present Danger (1994)
#  18     225     136       5  879540707  Mr. Smith Goes to Washington (1939)
#  19     225     705       5  879540707           Singin' in the Rain (1952)
#  39     939    1277       5  880261945
#  40     939     476       5  880261974
#  41     939     106       3  880262019
#  42     939     424       3  880262019
#  43     939    1023       4  880262057
#  44     939     818       3  880262057
#  45     939    1051       5  880262090
#  46     939     934       3  880262139
#  47     939     931       2  880262196
#  48     939     254       3  880262319
#
#                                        itemName
#  0                           Jackal, The (1997)
#  1                    Kull the Conqueror (1997)
#  2                             G.I. Jane (1997)
#  3           Mortal Kombat: Annihilation (1997)
#  4                    Kull the Conqueror (1997)
#  5                               Contact (1997)
#  6                        Godfather, The (1972)
#  7                      Dead Man Walking (1995)
#  8                          Men in Black (1997)
#  9                 Sense and Sensibility (1995)
#  10                             Hercules (1997)
#  11                     That Old Feeling (1997)
#  12                               Ransom (1996)
#  13             Star Trek: First Contact (1996)
#  14                          Primal Fear (1996)
#  15                        Jerry Maguire (1996)
#  16             My Best Friend's Wedding (1997)
#  17                   Mr. Holland's Opus (1995)
#  18          People vs. Larry Flynt, The (1996)
#  19                       Secrets & Lies (1996)
#  20                             Face/Off (1997)
#  21       Lost World: Jurassic Park, The (1997)
#  22                   Courage Under Fire (1996)
#  23                                 Emma (1996)
#  24                Up Close and Personal (1996)
#  25                              Sabrina (1995)
#  26               Independence Day (ID4) (1996)
#  27                              Twister (1996)
#  28                  Mission: Impossible (1996)
#  29                                 Jack (1996)
#  30          Father of the Bride Part II (1995)
#  31                         Broken Arrow (1996)
#  32                               Eraser (1996)
#  33            Mirror Has Two Faces, The (1996)
#  34                           Juror, The (1996)
#  35                            Mr. Wrong (1996)
#  36                     Grumpier Old Men (1995)
#  37                     Glimmer Man, The (1996)
#  38                 Nutty Professor, The (1996)
#  39                           Set It Off (1996)
#  40                First Wives Club, The (1996)
#  41                           Diabolique (1996)
#  42  Children of the Corn: The Gathering (1996)
#  43                         Fathers' Day (1997)
#  44                               Girl 6 (1996)
#  45                       Associate, The (1996)
#  46                 Preacher's Wife, The (1996)
#  47            Island of Dr. Moreau, The (1996)
#  48                       Batman & Robin (1997)  ,
#       userId  itemId  rating  timestamp  \
#  0       936     272       4  886831374
#  1       936     313       4  886831374
#  2       936     258       3  886831374
#  3       936     904       5  886831415
#  4       936     268       4  886831415
#  ..      ...     ...     ...        ...
#  137     936    1007       5  886833795
#  138     936    1097       5  886833795
#  139     936     547       5  886833795
#  140     936     255       5  886833795
#  141     936    1129       5  886833795
#
#                                      itemName
#  0                   Good Will Hunting (1997)
#  1                             Titanic (1997)
#  2                             Contact (1997)
#  3    Ma vie en rose (My Life in Pink) (1997)
#  4                         Chasing Amy (1997)
#  ..                                       ...
#  137               Waiting for Guffman (1996)
#  138                  Hate (Haine, La) (1995)
#  139    Young Poisoner's Handbook, The (1995)
#  140          My Best Friend's Wedding (1997)
#  141                 Chungking Express (1994)
#
#  [142 rows x 5 columns],
#      userId  itemId  rating  timestamp  \
#  0      930     286       3  879533975
#  1      930     288       1  879534001
#  2      930     245       3  879534165
#  3      930     690       3  879534335
#  4      930      50       2  879534410
#  ..     ...     ...     ...        ...
#  58     930     153       2  879535685
#  59     930     210       2  879535713
#  60     930     175       2  879535713
